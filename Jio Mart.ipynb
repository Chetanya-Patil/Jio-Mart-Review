# %% [markdown]
#  This is the review from Apr 28,2020 – May 28,2020

# %% [markdown]
# # What is WordCloud?

# %% [markdown]
# Many times you might have seen a cloud filled with lots of words in different sizes, which represent the frequency or the importance of each word. This is called Tag Cloud or WordCloud. This tool will be quite handy for exploring text data and making your report more lively.

# %%
#Importing all required libraries 
import numpy as np
import pandas as pd
from os import path
from PIL import Image
from wordcloud import WordCloud, STOPWORDS, ImageColorGenerator
import matplotlib.pyplot as plt

# %%
#import the data 
df = pd.read_csv("C:/Users/chaitanya_patil/Desktop/nltk_folder/jio Mart/reviews_googleplay_1590637826.csv",skiprows=0,encoding= 'unicode_escape')
df
# Out:
#                 Date                AppID  \
# 0    5/27/2020 19:11  in.digital.reliance
# 1    5/27/2020 18:17  in.digital.reliance
# 2    5/27/2020 17:27  in.digital.reliance
# 3    5/27/2020 16:52  in.digital.reliance
# 4    5/27/2020 16:42  in.digital.reliance
# 5    5/27/2020 16:39  in.digital.reliance
# 6    5/27/2020 16:26  in.digital.reliance
# 7    5/27/2020 16:20  in.digital.reliance
# 8    5/27/2020 15:55  in.digital.reliance
# 9    5/27/2020 15:32  in.digital.reliance
# 10   5/27/2020 15:15  in.digital.reliance
# 11   5/27/2020 14:30  in.digital.reliance
# 12   5/27/2020 13:54  in.digital.reliance
# 13   5/27/2020 12:40  in.digital.reliance
# 14   5/27/2020 11:30  in.digital.reliance
# 15   5/27/2020 10:07  in.digital.reliance
# 16   5/27/2020 10:04  in.digital.reliance
# 17    5/27/2020 9:26  in.digital.reliance
# 18    5/27/2020 8:50  in.digital.reliance
# 19    5/27/2020 8:28  in.digital.reliance
# 20    5/27/2020 8:14  in.digital.reliance
# ...

# %% [markdown]
# Sorted data to be require for analysing the most frequent word in the jio mart Review.

# %%
sorted_data = df[["Author","Review"]]
sorted_data
# Out:
#                             Author  \
# 0                   Kailash Nemade
# 1                Joydeep Mukherjee
# 2                     h7t parjapat
# 3                     Rajan Pandey
# 4                  sandeep bawalia
# 5      chanakya à¤à¤¾à¤£à¤à¥à¤¯
# 6                     Reddy Madava
# 7                     Rakesh Ghosh
# 8                 Ahammed Mahamood
# 9                      Vinit Kumar
# 10      PANKAJ THAKUR PAHARI BANDA
# 11                       Rishu Sah
# 12                   subham mittal
# 13                  Shekhar Raghav
# 14                  omeshwar sepat
# 15                         Vivek I
# 16               nishu kumar singh
# 17              Abhishek jain Shah
# 18                 Surendar Tejesh
# 19               amit kumar Mishra
# 20                     Sagar Pawar
# 21         Jandhyala Rajya Lakshmi
# 22       Maddu Srilakshmi Narayana
# 23             Shifa makeup Divine
# 24               MANNU KUMAR SINGH
# ...

# %%
sorted_data.Review
#This are the review for thr jio mart(Relaince Digital shopping online platform) application
# Out:
# 0                     Very good online shopping platform
# 1                                         Cant log in...
# 2                                                   Best
# 3                                          Very good app
# 4                                                Amazing
# 5                                               Too good
# 6                                                   Good
# 7                                                   Nice
# 8                                     Bad experience !!!
# 9      Veriy Nice Shopping App Amazon and Flipkart Ta...
# 10                                                   Gud
# 11                          Des hitme .....janhitme jari
# 12                                     Aatnirbhar bharat
# 13                                       Fantastic app..
# 14           Not able to login 15 day continue Probleum.
# 15     Order supposed to be delivered on 24th is stil...
# ...

# %%
df.Review
# Out:
# 0                     Very good online shopping platform
# 1                                         Cant log in...
# 2                                                   Best
# 3                                          Very good app
# 4                                                Amazing
# 5                                               Too good
# 6                                                   Good
# 7                                                   Nice
# 8                                     Bad experience !!!
# 9      Veriy Nice Shopping App Amazon and Flipkart Ta...
# 10                                                   Gud
# 11                          Des hitme .....janhitme jari
# 12                                     Aatnirbhar bharat
# 13                                       Fantastic app..
# 14           Not able to login 15 day continue Probleum.
# 15     Order supposed to be delivered on 24th is stil...
# ...

# %% [markdown]
# Let's integrate all review in one text file to work with them.

# %%
text = " ".join(review for review in df.Review)
print("There are {} words in the combination of all review.".format(len(text)))
# Out:
# There are 23273 words in the combination of all review.

# %%
#count of the NaN value float found means NaN value.
df['Review'].isnull().sum()
# Out:
# 0

# %%
df['Review'].isnull().values.any()
# Out:
# False

# %%
#Replacing the NaN value by jio
df["Review"].fillna("jio", inplace = True)

# %%
df['Review'].isnull().sum()
#Here we get zero number of NaN VALUE
# Out:
# 0

# %%
text = " ".join(review for review in df.Review)
print(" There are {} words  in the combination of all review.".format(len(text)))
# Out:
#  There are 23273 words  in the combination of all review.

# %%
#Create stopword list:
stopwords = set(STOPWORDS)
stopwords.update(["Gd", "Nyc"])

# %%
#Generate a word cloud image
wordcloud = WordCloud(stopwords=stopwords,background_color="white").generate(text)

#save the word cloud to home
wordcloud.to_file("C:/Users/chaitanya_patil/Desktop/nltk_folder/jio Mart/jio_review.png")

# %%
#Display the generated image:
# The matplotlib way:
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.show()

# %% [markdown]
# This wordcloud shows that the jio mart application is delivering it's services in good quality.
# But there are some word to be listed here show that there are some problem regarding this application or we can say this servie.
# As we know it's a starting era of this indian mart.They will definately fixing this all issues.
#
# "how to present the relationship between the words.-----Text Marketing"
